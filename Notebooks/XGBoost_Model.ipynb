# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

from xgboost import XGBClassifier

import joblib
import os

# %%
df = pd.read_csv(r'../dataset/train.csv')
print(df.columns)
df.shape
# Out:
# Index(['id', 'health_condition', 'sleep_duration', 'heart_rate', 'bmi',
#        'calorie_expenditure', 'step_count', 'exercise_duration',
#        'water_intake', 'diet_type', 'stress_level', 'sleep_quality',
#        'physical_activity_level', 'smoking_alcohol', 'gender'],
#       dtype='str')
# (690088, 15)

# %%
Target= "health_condition"

Features= [
    c for c in df.columns
    if c not in ["id", Target,]
]

# %%
numeric_cols = [
    "sleep_duration",
    "heart_rate",
    "bmi",
    "calorie_expenditure",
    "step_count",
    "exercise_duration",
    "water_intake"
]

categorical_cols = [
    "diet_type",
    "stress_level",
    "sleep_quality",
    "physical_activity_level",
    "smoking_alcohol",
    "gender"
]


defined_features = numeric_cols + categorical_cols

# Check count
print("Number of numerical columns:", len(numeric_cols))
print("Number of categorical columns:", len(categorical_cols))
print("Total defined feature columns:", len(defined_features))
# Out:
# Number of numerical columns: 7
# Number of categorical columns: 6
# Total defined feature columns: 13

# %%
medians = {}
for col in numeric_cols:
    med = df[col].median()
    medians[col] = med
    df[col] = df[col].fillna(med)

for col in categorical_cols:
    df[col] = df[col].fillna('missing')

medians
# Out:
# {'sleep_duration': np.float64(6.99),
#  'heart_rate': np.float64(75.1),
#  'bmi': np.float64(22.99),
#  'calorie_expenditure': np.float64(2241.0),
#  'step_count': np.float64(8856.0),
#  'exercise_duration': np.float64(39.4),
#  'water_intake': np.float64(2.17)}

# %%
df["bmi_activity_score"] = (
    df["bmi"] *
    df["exercise_duration"]
)

df["bmi_hydration_score"] = (
    df["bmi"] *
    df["water_intake"]
)

# %%
encoders = {}

for col in categorical_cols:
    label_encoder = LabelEncoder()
    df[col] = label_encoder.fit_transform(df[col])

    encoders[col] = label_encoder


y_encoder = LabelEncoder()
df["target_enc"] = y_encoder.fit_transform(df[Target])

print("Target Mapping:")
print(dict(zip(
    y_encoder.classes_,
    y_encoder.transform(y_encoder.classes_)
)))
# Out:
# Target Mapping:
# {'at-risk': np.int64(0), 'fit': np.int64(1), 'unhealthy': np.int64(2)}

# %%
x = df[Features]
y = df["target_enc"]

# %%
x_train, x_valid, y_train, y_valid = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print(x_train.shape)
print(x_valid.shape)
# Out:
# (552070, 13)
# (138018, 13)

# %%
xgb_model = XGBClassifier(
    n_estimators=400,
    max_depth=8,
    learning_rate=0.03,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="multi:softprob",
    num_class=3,
    random_state=42,
    eval_metric="mlogloss",
)


xgb_model.fit(
    x_train,
    y_train,
    eval_set=[(x_valid, y_valid)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:0.48576
# [1]	validation_0-mlogloss:0.46038
# [2]	validation_0-mlogloss:0.43565
# [3]	validation_0-mlogloss:0.41883
# [4]	validation_0-mlogloss:0.40413
# [5]	validation_0-mlogloss:0.38779
# [6]	validation_0-mlogloss:0.37215
# [7]	validation_0-mlogloss:0.35812
# [8]	validation_0-mlogloss:0.34677
# [9]	validation_0-mlogloss:0.33686
# [10]	validation_0-mlogloss:0.32951
# [11]	validation_0-mlogloss:0.32018
# [12]	validation_0-mlogloss:0.31196
# [13]	validation_0-mlogloss:0.30233
# [14]	validation_0-mlogloss:0.29475
# [15]	validation_0-mlogloss:0.28618
# [16]	validation_0-mlogloss:0.28171
# [17]	validation_0-mlogloss:0.27561
# [18]	validation_0-mlogloss:0.26822
# [19]	validation_0-mlogloss:0.26086
# [20]	validation_0-mlogloss:0.25553
# [21]	validation_0-mlogloss:0.25037
# [22]	validation_0-mlogloss:0.24692
# [23]	validation_0-mlogloss:0.24158
# [24]	validation_0-mlogloss:0.23717
# [25]	validation_0-mlogloss:0.23343
# [26]	validation_0-mlogloss:0.22826
# [27]	validation_0-mlogloss:0.22465
# [28]	validation_0-mlogloss:0.22035
# [29]	validation_0-mlogloss:0.21697
# [30]	validation_0-mlogloss:0.21219
# [31]	validation_0-mlogloss:0.20996
# [32]	validation_0-mlogloss:0.20735
# [33]	validation_0-mlogloss:0.20415
# [34]	validation_0-mlogloss:0.20147
# [35]	validation_0-mlogloss:0.19774
# [36]	validation_0-mlogloss:0.19474
# [37]	validation_0-mlogloss:0.19265
# [38]	validation_0-mlogloss:0.18904
# [39]	validation_0-mlogloss:0.18543
# [40]	validation_0-mlogloss:0.18286
# [41]	validation_0-mlogloss:0.18033
# [42]	validation_0-mlogloss:0.17728
# [43]	validation_0-mlogloss:0.17510
# [44]	validation_0-mlogloss:0.17229
# [45]	validation_0-mlogloss:0.16972
# [46]	validation_0-mlogloss:0.16721
# [47]	validation_0-mlogloss:0.16523
# [48]	validation_0-mlogloss:0.16275
# [49]	validation_0-mlogloss:0.16051
# [50]	validation_0-mlogloss:0.15803
# [51]	validation_0-mlogloss:0.15574
# [52]	validation_0-mlogloss:0.15412
# [53]	validation_0-mlogloss:0.15187
# [54]	validation_0-mlogloss:0.15054
# [55]	validation_0-mlogloss:0.14885
# [56]	validation_0-mlogloss:0.14711
# [57]	validation_0-mlogloss:0.14564
# [58]	validation_0-mlogloss:0.14480
# [59]	validation_0-mlogloss:0.14296
# [60]	validation_0-mlogloss:0.14125
# [61]	validation_0-mlogloss:0.13987
# [62]	validation_0-mlogloss:0.13821
# [63]	validation_0-mlogloss:0.13655
# [64]	validation_0-mlogloss:0.13515
# [65]	validation_0-mlogloss:0.13455
# [66]	validation_0-mlogloss:0.13339
# [67]	validation_0-mlogloss:0.13191
# [68]	validation_0-mlogloss:0.13068
# [69]	validation_0-mlogloss:0.12988
# [70]	validation_0-mlogloss:0.12926
# [71]	validation_0-mlogloss:0.12822
# [72]	validation_0-mlogloss:0.12715
# [73]	validation_0-mlogloss:0.12627
# [74]	validation_0-mlogloss:0.12569
# [75]	validation_0-mlogloss:0.12451
# [76]	validation_0-mlogloss:0.12333
# [77]	validation_0-mlogloss:0.12225
# [78]	validation_0-mlogloss:0.12172
# [79]	validation_0-mlogloss:0.12105
# [80]	validation_0-mlogloss:0.12043
# [81]	validation_0-mlogloss:0.11968
# [82]	validation_0-mlogloss:0.11909
# [83]	validation_0-mlogloss:0.11827
# [84]	validation_0-mlogloss:0.11732
# [85]	validation_0-mlogloss:0.11666
# [86]	validation_0-mlogloss:0.11588
# [87]	validation_0-mlogloss:0.11543
# [88]	validation_0-mlogloss:0.11463
# [89]	validation_0-mlogloss:0.11413
# [90]	validation_0-mlogloss:0.11331
# [91]	validation_0-mlogloss:0.11273
# [92]	validation_0-mlogloss:0.11200
# [93]	validation_0-mlogloss:0.11151
# [94]	validation_0-mlogloss:0.11081
# [95]	validation_0-mlogloss:0.11032
# [96]	validation_0-mlogloss:0.11010
# [97]	validation_0-mlogloss:0.10960
# [98]	validation_0-mlogloss:0.10911
# [99]	validation_0-mlogloss:0.10850
# [100]	validation_0-mlogloss:0.10808
# [101]	validation_0-mlogloss:0.10776
# [102]	validation_0-mlogloss:0.10729
# [103]	validation_0-mlogloss:0.10692
# [104]	validation_0-mlogloss:0.10637
# [105]	validation_0-mlogloss:0.10602
# [106]	validation_0-mlogloss:0.10548
# [107]	validation_0-mlogloss:0.10511
# [108]	validation_0-mlogloss:0.10473
# [109]	validation_0-mlogloss:0.10445
# [110]	validation_0-mlogloss:0.10418
# [111]	validation_0-mlogloss:0.10382
# [112]	validation_0-mlogloss:0.10347
# [113]	validation_0-mlogloss:0.10307
# [114]	validation_0-mlogloss:0.10266
# [115]	validation_0-mlogloss:0.10227
# [116]	validation_0-mlogloss:0.10196
# [117]	validation_0-mlogloss:0.10172
# [118]	validation_0-mlogloss:0.10153
# [119]	validation_0-mlogloss:0.10128
# [120]	validation_0-mlogloss:0.10112
# [121]	validation_0-mlogloss:0.10092
# [122]	validation_0-mlogloss:0.10069
# [123]	validation_0-mlogloss:0.10044
# [124]	validation_0-mlogloss:0.10010
# [125]	validation_0-mlogloss:0.09989
# [126]	validation_0-mlogloss:0.09956
# [127]	validation_0-mlogloss:0.09923
# [128]	validation_0-mlogloss:0.09907
# [129]	validation_0-mlogloss:0.09888
# [130]	validation_0-mlogloss:0.09865
# [131]	validation_0-mlogloss:0.09837
# [132]	validation_0-mlogloss:0.09811
# [133]	validation_0-mlogloss:0.09799
# [134]	validation_0-mlogloss:0.09774
# [135]	validation_0-mlogloss:0.09763
# [136]	validation_0-mlogloss:0.09741
# [137]	validation_0-mlogloss:0.09722
# [138]	validation_0-mlogloss:0.09711
# [139]	validation_0-mlogloss:0.09691
# [140]	validation_0-mlogloss:0.09680
# [141]	validation_0-mlogloss:0.09659
# [142]	validation_0-mlogloss:0.09650
# [143]	validation_0-mlogloss:0.09643
# [144]	validation_0-mlogloss:0.09628
# [145]	validation_0-mlogloss:0.09612
# [146]	validation_0-mlogloss:0.09591
# [147]	validation_0-mlogloss:0.09585
# [148]	validation_0-mlogloss:0.09567
# [149]	validation_0-mlogloss:0.09556
# [150]	validation_0-mlogloss:0.09541
# [151]	validation_0-mlogloss:0.09523
# [152]	validation_0-mlogloss:0.09507
# [153]	validation_0-mlogloss:0.09498
# [154]	validation_0-mlogloss:0.09486
# [155]	validation_0-mlogloss:0.09474
# [156]	validation_0-mlogloss:0.09459
# [157]	validation_0-mlogloss:0.09449
# [158]	validation_0-mlogloss:0.09438
# [159]	validation_0-mlogloss:0.09426
# [160]	validation_0-mlogloss:0.09420
# [161]	validation_0-mlogloss:0.09405
# [162]	validation_0-mlogloss:0.09400
# [163]	validation_0-mlogloss:0.09392
# [164]	validation_0-mlogloss:0.09384
# [165]	validation_0-mlogloss:0.09373
# [166]	validation_0-mlogloss:0.09363
# [167]	validation_0-mlogloss:0.09353
# [168]	validation_0-mlogloss:0.09344
# [169]	validation_0-mlogloss:0.09336
# [170]	validation_0-mlogloss:0.09323
# [171]	validation_0-mlogloss:0.09314
# [172]	validation_0-mlogloss:0.09305
# [173]	validation_0-mlogloss:0.09296
# [174]	validation_0-mlogloss:0.09287
# [175]	validation_0-mlogloss:0.09277
# [176]	validation_0-mlogloss:0.09271
# [177]	validation_0-mlogloss:0.09268
# [178]	validation_0-mlogloss:0.09263
# [179]	validation_0-mlogloss:0.09259
# [180]	validation_0-mlogloss:0.09253
# [181]	validation_0-mlogloss:0.09247
# [182]	validation_0-mlogloss:0.09243
# [183]	validation_0-mlogloss:0.09237
# [184]	validation_0-mlogloss:0.09230
# [185]	validation_0-mlogloss:0.09222
# [186]	validation_0-mlogloss:0.09215
# [187]	validation_0-mlogloss:0.09209
# [188]	validation_0-mlogloss:0.09205
# [189]	validation_0-mlogloss:0.09196
# [190]	validation_0-mlogloss:0.09191
# [191]	validation_0-mlogloss:0.09188
# [192]	validation_0-mlogloss:0.09184
# [193]	validation_0-mlogloss:0.09180
# [194]	validation_0-mlogloss:0.09174
# [195]	validation_0-mlogloss:0.09172
# [196]	validation_0-mlogloss:0.09169
# [197]	validation_0-mlogloss:0.09166
# [198]	validation_0-mlogloss:0.09164
# [199]	validation_0-mlogloss:0.09160
# [200]	validation_0-mlogloss:0.09158
# [201]	validation_0-mlogloss:0.09153
# [202]	validation_0-mlogloss:0.09148
# [203]	validation_0-mlogloss:0.09144
# [204]	validation_0-mlogloss:0.09139
# [205]	validation_0-mlogloss:0.09134
# [206]	validation_0-mlogloss:0.09132
# [207]	validation_0-mlogloss:0.09130
# [208]	validation_0-mlogloss:0.09127
# [209]	validation_0-mlogloss:0.09123
# [210]	validation_0-mlogloss:0.09119
# [211]	validation_0-mlogloss:0.09116
# [212]	validation_0-mlogloss:0.09110
# [213]	validation_0-mlogloss:0.09107
# [214]	validation_0-mlogloss:0.09104
# [215]	validation_0-mlogloss:0.09102
# [216]	validation_0-mlogloss:0.09100
# [217]	validation_0-mlogloss:0.09097
# [218]	validation_0-mlogloss:0.09095
# [219]	validation_0-mlogloss:0.09092
# [220]	validation_0-mlogloss:0.09090
# [221]	validation_0-mlogloss:0.09085
# [222]	validation_0-mlogloss:0.09083
# [223]	validation_0-mlogloss:0.09081
# [224]	validation_0-mlogloss:0.09078
# [225]	validation_0-mlogloss:0.09075
# [226]	validation_0-mlogloss:0.09073
# [227]	validation_0-mlogloss:0.09070
# [228]	validation_0-mlogloss:0.09070
# [229]	validation_0-mlogloss:0.09067
# [230]	validation_0-mlogloss:0.09063
# [231]	validation_0-mlogloss:0.09061
# [232]	validation_0-mlogloss:0.09057
# [233]	validation_0-mlogloss:0.09055
# [234]	validation_0-mlogloss:0.09053
# [235]	validation_0-mlogloss:0.09051
# [236]	validation_0-mlogloss:0.09049
# [237]	validation_0-mlogloss:0.09047
# [238]	validation_0-mlogloss:0.09046
# [239]	validation_0-mlogloss:0.09045
# [240]	validation_0-mlogloss:0.09043
# [241]	validation_0-mlogloss:0.09040
# [242]	validation_0-mlogloss:0.09037
# [243]	validation_0-mlogloss:0.09035
# [244]	validation_0-mlogloss:0.09032
# [245]	validation_0-mlogloss:0.09030
# [246]	validation_0-mlogloss:0.09029
# [247]	validation_0-mlogloss:0.09028
# [248]	validation_0-mlogloss:0.09026
# [249]	validation_0-mlogloss:0.09026
# [250]	validation_0-mlogloss:0.09024
# [251]	validation_0-mlogloss:0.09023
# [252]	validation_0-mlogloss:0.09022
# [253]	validation_0-mlogloss:0.09020
# [254]	validation_0-mlogloss:0.09018
# [255]	validation_0-mlogloss:0.09017
# [256]	validation_0-mlogloss:0.09016
# [257]	validation_0-mlogloss:0.09015
# [258]	validation_0-mlogloss:0.09014
# [259]	validation_0-mlogloss:0.09012
# [260]	validation_0-mlogloss:0.09012
# [261]	validation_0-mlogloss:0.09010
# [262]	validation_0-mlogloss:0.09009
# [263]	validation_0-mlogloss:0.09008
# [264]	validation_0-mlogloss:0.09007
# [265]	validation_0-mlogloss:0.09006
# [266]	validation_0-mlogloss:0.09005
# [267]	validation_0-mlogloss:0.09004
# [268]	validation_0-mlogloss:0.09003
# [269]	validation_0-mlogloss:0.09001
# [270]	validation_0-mlogloss:0.09001
# [271]	validation_0-mlogloss:0.09000
# [272]	validation_0-mlogloss:0.08999
# [273]	validation_0-mlogloss:0.08998
# [274]	validation_0-mlogloss:0.08997
# [275]	validation_0-mlogloss:0.08996
# [276]	validation_0-mlogloss:0.08996
# [277]	validation_0-mlogloss:0.08995
# [278]	validation_0-mlogloss:0.08994
# [279]	validation_0-mlogloss:0.08994
# [280]	validation_0-mlogloss:0.08993
# [281]	validation_0-mlogloss:0.08993
# [282]	validation_0-mlogloss:0.08992
# [283]	validation_0-mlogloss:0.08991
# [284]	validation_0-mlogloss:0.08990
# [285]	validation_0-mlogloss:0.08990
# [286]	validation_0-mlogloss:0.08988
# [287]	validation_0-mlogloss:0.08988
# [288]	validation_0-mlogloss:0.08987
# [289]	validation_0-mlogloss:0.08986
# [290]	validation_0-mlogloss:0.08985
# [291]	validation_0-mlogloss:0.08984
# [292]	validation_0-mlogloss:0.08984
# [293]	validation_0-mlogloss:0.08983
# [294]	validation_0-mlogloss:0.08983
# [295]	validation_0-mlogloss:0.08983
# [296]	validation_0-mlogloss:0.08983
# [297]	validation_0-mlogloss:0.08981
# [298]	validation_0-mlogloss:0.08981
# [299]	validation_0-mlogloss:0.08980
# [300]	validation_0-mlogloss:0.08980
# [301]	validation_0-mlogloss:0.08979
# [302]	validation_0-mlogloss:0.08978
# [303]	validation_0-mlogloss:0.08978
# [304]	validation_0-mlogloss:0.08978
# [305]	validation_0-mlogloss:0.08977
# [306]	validation_0-mlogloss:0.08975
# [307]	validation_0-mlogloss:0.08975
# [308]	validation_0-mlogloss:0.08974
# [309]	validation_0-mlogloss:0.08974
# [310]	validation_0-mlogloss:0.08974
# [311]	validation_0-mlogloss:0.08973
# [312]	validation_0-mlogloss:0.08973
# [313]	validation_0-mlogloss:0.08972
# [314]	validation_0-mlogloss:0.08972
# [315]	validation_0-mlogloss:0.08972
# [316]	validation_0-mlogloss:0.08971
# [317]	validation_0-mlogloss:0.08970
# [318]	validation_0-mlogloss:0.08969
# [319]	validation_0-mlogloss:0.08969
# [320]	validation_0-mlogloss:0.08969
# [321]	validation_0-mlogloss:0.08968
# [322]	validation_0-mlogloss:0.08968
# [323]	validation_0-mlogloss:0.08968
# [324]	validation_0-mlogloss:0.08967
# [325]	validation_0-mlogloss:0.08967
# [326]	validation_0-mlogloss:0.08967
# [327]	validation_0-mlogloss:0.08966
# [328]	validation_0-mlogloss:0.08966
# [329]	validation_0-mlogloss:0.08965
# [330]	validation_0-mlogloss:0.08964
# [331]	validation_0-mlogloss:0.08964
# [332]	validation_0-mlogloss:0.08964
# [333]	validation_0-mlogloss:0.08963
# [334]	validation_0-mlogloss:0.08962
# [335]	validation_0-mlogloss:0.08962
# [336]	validation_0-mlogloss:0.08961
# [337]	validation_0-mlogloss:0.08960
# [338]	validation_0-mlogloss:0.08960
# [339]	validation_0-mlogloss:0.08960
# [340]	validation_0-mlogloss:0.08959
# [341]	validation_0-mlogloss:0.08959
# [342]	validation_0-mlogloss:0.08958
# [343]	validation_0-mlogloss:0.08957
# [344]	validation_0-mlogloss:0.08956
# [345]	validation_0-mlogloss:0.08956
# [346]	validation_0-mlogloss:0.08956
# [347]	validation_0-mlogloss:0.08955
# [348]	validation_0-mlogloss:0.08955
# [349]	validation_0-mlogloss:0.08955
# [350]	validation_0-mlogloss:0.08955
# [351]	validation_0-mlogloss:0.08954
# [352]	validation_0-mlogloss:0.08954
# [353]	validation_0-mlogloss:0.08953
# [354]	validation_0-mlogloss:0.08953
# [355]	validation_0-mlogloss:0.08952
# [356]	validation_0-mlogloss:0.08952
# [357]	validation_0-mlogloss:0.08951
# [358]	validation_0-mlogloss:0.08950
# [359]	validation_0-mlogloss:0.08950
# [360]	validation_0-mlogloss:0.08950
# [361]	validation_0-mlogloss:0.08949
# [362]	validation_0-mlogloss:0.08949
# [363]	validation_0-mlogloss:0.08948
# [364]	validation_0-mlogloss:0.08948
# [365]	validation_0-mlogloss:0.08948
# [366]	validation_0-mlogloss:0.08948
# [367]	validation_0-mlogloss:0.08948
# [368]	validation_0-mlogloss:0.08947
# [369]	validation_0-mlogloss:0.08947
# [370]	validation_0-mlogloss:0.08947
# [371]	validation_0-mlogloss:0.08947
# [372]	validation_0-mlogloss:0.08946
# [373]	validation_0-mlogloss:0.08945
# [374]	validation_0-mlogloss:0.08945
# [375]	validation_0-mlogloss:0.08944
# [376]	validation_0-mlogloss:0.08944
# [377]	validation_0-mlogloss:0.08943
# [378]	validation_0-mlogloss:0.08943
# [379]	validation_0-mlogloss:0.08943
# [380]	validation_0-mlogloss:0.08942
# [381]	validation_0-mlogloss:0.08942
# [382]	validation_0-mlogloss:0.08942
# [383]	validation_0-mlogloss:0.08941
# [384]	validation_0-mlogloss:0.08941
# [385]	validation_0-mlogloss:0.08941
# [386]	validation_0-mlogloss:0.08940
# [387]	validation_0-mlogloss:0.08940
# [388]	validation_0-mlogloss:0.08940
# [389]	validation_0-mlogloss:0.08940
# [390]	validation_0-mlogloss:0.08939
# [391]	validation_0-mlogloss:0.08939
# [392]	validation_0-mlogloss:0.08939
# [393]	validation_0-mlogloss:0.08938
# [394]	validation_0-mlogloss:0.08938
# [395]	validation_0-mlogloss:0.08938
# [396]	validation_0-mlogloss:0.08938
# [397]	validation_0-mlogloss:0.08938
# [398]	validation_0-mlogloss:0.08937
# [399]	validation_0-mlogloss:0.08937
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None, num_class=3, ...)

# %%
y_pred = xgb_model.predict(x_valid)


accuracy = accuracy_score(y_valid, y_pred)
f1 = f1_score(y_valid, y_pred, average="macro")


print(f"\nAccuracy: {accuracy * 100:.2f}%\n")
print("F1 Score:" , f1*100)


print(classification_report(
    y_valid,
    y_pred,
    target_names=y_encoder.classes_
))


cm = confusion_matrix(y_valid, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=y_encoder.classes_
)

disp.plot(cmap="Blues")
plt.show()
# Out:
# Accuracy: 96.77%
#
# F1 Score: 91.21482996190338
#               precision    recall  f1-score   support
#
#      at-risk       0.97      0.99      0.98    118512
#          fit       0.94      0.83      0.88      7961
#    unhealthy       0.95      0.81      0.87     11545
#
#     accuracy                           0.97    138018
#    macro avg       0.95      0.88      0.91    138018
# weighted avg       0.97      0.97      0.97    138018

# %%
os.makedirs("../models", exist_ok=True)


preprocessing_info = {
    "numeric_columns": numeric_cols,
    "categorical_columns": categorical_cols,
    "numeric_medians": medians,
    "categorical_fill": "missing"
}


joblib.dump(xgb_model, "../models/xgboost_model.pkl")
joblib.dump(encoders, "../models/feature_encoders.pkl")
joblib.dump(y_encoder, "../models/target_encoder.pkl")
joblib.dump(Features, "../models/feature_names.pkl")
joblib.dump(preprocessing_info, "../models/preprocessing_info.pkl")

print("All artifacts saved successfully!")

print(os.listdir("../models"))
# Out:
# All artifacts saved successfully!
# ['feature_encoders.pkl', 'feature_names.pkl', 'preprocessing_info.pkl', 'target_encoder.pkl', 'xgboost_model.pkl']
